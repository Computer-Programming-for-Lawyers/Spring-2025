# %% [markdown]
# ![AI_image.jpeg](AI_image.jpeg)
#
# # Lab 7: Finale
#
# <br><br><br>
#
# ## 1. Grievances (5 minutes)
#
# <br><br><br>
#
# ## 2. Functions Review (20 minutes)
#
# <br><br><br>
#
# ## 3. Coding with ChatGPT.

# %% [markdown]
# ![g](grievances.jpeg)
#
# # 1. Grievances.
#
# ## That homework was something else!

# %% [markdown]
# <img src="housing.jpeg" alt="housing" width="800"/>
#
# # 2. Functions Review: Houses
#
# # Breakding down a big task into smaller sub tasks.
#
# ### A. Defining Beginning and End States: house.csv. (Data exploration)
#
#
# ### B. Understanding what needs to be done, at small scale: Functions (Gameplanning/Program Structuring == Subtasks)
#
#
# ### C. Filling in the spaces. Pseudocode.
#
#
# ### D. Execution: Coding, alternatively, GenAI/Debugging/Testing.

# %%
# Pseudocode for housing here.
## Library will be called housing.py

# Summary:
# Know what your input/data ais
# Know where you need to end up
# Fill in the gaps.

# FX1: Get the data into your program
# Accept a filename
# return a pandas DataFrame

# FX2: Clean the data / turn it into something more manipulble
# Accept a dataframe
# Return a dataframe

# Goal 1: FX3: Returning some summary statistics
# Goal 2: FX4: Displaying charts/visuals

# FX5: function that runs all of the above

# %% [markdown]
# ![daddy](daddyAI.png)
#
# # 3. The brave new world of AI assisted programming

# %%
# Coding time_elapsed with ChatGPT

# %% [markdown]
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank
# # This Markdown is Intentionally Left Blank

# %%
import housing

housing.show('house.csv')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import housing
# ----> 3 housing.show('house.csv')
#
# File /workspaces/Fall-2024/labs/week-7/housing.py:47, in show(csvfile)
#      45 def show(csvfile):
#      46     rawdata = read_data(csvfile)
# ---> 47     clean_data = clean_data(rawdata)
#      48     give_summary_stats(clean_data)
#      49     visualize_data(clean_data)
#
# UnboundLocalError: cannot access local variable 'clean_data' where it is not associated with a value

# %%
# Scratch
# Import the data
# Identify and examine the data
# Clean the data (take a subset of rows and columns)
# Visualize with the data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
# setting the dimensions of the plot
# Examine the data and return summary statistics

# Do some data cleaning with arbitrary logic.
# Read the data
# a Function that takes in the name/address of a .csv file 
# and turns it into a Pandas dataframe and returns it
def read_data(csvfile):
    raw_data_dataframe = pd.read_csv(csvfile)
    return raw_data_dataframe

def clean_data(raw_data_dataframe):
    # Exclude some states
    # Exclude some zipcodes
    # Rename some places . . . etc
    return clean_dataframe

def give_summary_stats(clean_dataframe):
    # Give some summary statistics
    avg_price_by_city = housedata.groupby('State').mean('Price')
    # Other summaries
    print(avg_price_by_city)
    return null

# Do some visualizations (each should be a function)
def visualize_data(clean_dataframe, chart_type='bar'):

# Bar
# Scatter/Bubble
# Histogram
    fig, ax = plt.subplots(figsize=(30, 5))
    barplot = sns.barplot(data=avg_price_by_city, x='State', y='Price', ax=ax)
    barplot.set_xticklabels(barplot.get_xticklabels(), rotation=45)
    return null

def show(csvfile):
    rawdata = read_data(csvfile)
    clean_data = clean_data(rawdata)
    give_summary_stats(clean_data)
    visualize_data(clean_data)
# Out:
# /tmp/ipykernel_2678/4265048000.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   barplot.set_xticklabels(barplot.get_xticklabels(), rotation=45)
# [Text(0, 0, 'Arizona'),
#  Text(1, 0, 'California'),
#  Text(2, 0, 'Colorado'),
#  Text(3, 0, 'District of Columbia'),
#  Text(4, 0, 'Florida'),
#  Text(5, 0, 'Georgia'),
#  Text(6, 0, 'Illinois'),
#  Text(7, 0, 'Indiana'),
#  Text(8, 0, 'Kansas'),
#  Text(9, 0, 'Kentucky'),
#  Text(10, 0, 'Louisiana'),
#  Text(11, 0, 'Maryland'),
#  Text(12, 0, 'Michigan'),
#  Text(13, 0, 'Minnesota'),
#  Text(14, 0, 'Missouri'),
#  Text(15, 0, 'Nebraska'),
#  Text(16, 0, 'Nevada'),
#  Text(17, 0, 'New Mexico'),
#  Text(18, 0, 'New York'),
#  Text(19, 0, 'North Carolina'),
#  Text(20, 0, 'Ohio'),
#  Text(21, 0, 'Oklahoma'),
#  Text(22, 0, 'Oregon'),
#  Text(23, 0, 'Pennsylvania'),
#  Text(24, 0, 'Tennessee'),
#  Text(25, 0, 'Texas'),
#  Text(26, 0, 'Virginia'),
# ...
