# %%
STANDARD_DEDUCTION = 12400

# rate = 0

total_income = int(input("Enter your income:"))

taxable_income = total_income - STANDARD_DEDUCTION

if taxable_income <= 9875:
    rate = 10
#if it's not below 9875, then check if it's below 40124
elif taxable_income <= 40125:
    rate = 12
elif taxable_income <= 85525:
    rate = 22

print(rate)
# Out:
# 12

# %%
i = 0

while i < 5:
    print("Number:",i,"word",sep=";")
    i=i+1
# Out:
# Number:;0;word
# Number:;1;word
# Number:;2;word
# Number:;3;word
# Number:;4;word

# %%
print("this","is","a","sentence",sep=";")
# Out:
# this;is;a;sentence

# %% [markdown]
# ![image.png](attachment:image.png)
